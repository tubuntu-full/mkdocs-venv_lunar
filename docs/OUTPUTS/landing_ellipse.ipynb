# %% [markdown]
# # Landing Ellipse

# %% [markdown]
# ![image.png](attachment:e7c22fa7-fbb8-47dc-8acc-1561725159a7.png)
# https://www.youtube.com/watch?v=In5xf5DHiM4

# %%
# Input Dispersions

# %% [markdown]
# . . .

# %%
# Output Sensitivities

# %% [markdown]
# . . .
